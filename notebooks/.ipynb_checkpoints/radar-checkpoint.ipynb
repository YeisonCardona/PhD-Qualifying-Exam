# %%
import numpy as np

import matplotlib.pyplot as plt
from matplotlib.patches import Circle, RegularPolygon
from matplotlib.path import Path
from matplotlib.projections.polar import PolarAxes
from matplotlib.projections import register_projection
from matplotlib.spines import Spine
from matplotlib.transforms import Affine2D
import matplotlib 

font = {'size': 21}

matplotlib.rc('font', **font)


def radar_factory(num_vars, frame='circle'):
    """Create a radar chart with `num_vars` axes.

    This function creates a RadarAxes projection and registers it.

    Parameters
    ----------
    num_vars : int
        Number of variables for radar chart.
    frame : {'circle' | 'polygon'}
        Shape of frame surrounding axes.

    """
    # calculate evenly-spaced axis angles
    theta = np.linspace(0, 2*np.pi, num_vars, endpoint=False)

    class RadarAxes(PolarAxes):

        name = 'radar'

        def __init__(self, *args, **kwargs):
            super().__init__(*args, **kwargs)
            # rotate plot such that the first axis is at the top
            self.set_theta_zero_location('N')

        def fill(self, *args, closed=True, **kwargs):
            """Override fill so that line is closed by default"""
            return super().fill(closed=closed, *args, **kwargs)

        def plot(self, *args, **kwargs):
            """Override plot so that line is closed by default"""
            lines = super().plot(*args, **kwargs)
            for line in lines:
                self._close_line(line)

        def _close_line(self, line):
            x, y = line.get_data()
            # FIXME: markers at x[0], y[0] get doubled-up
            if x[0] != x[-1]:
                x = np.concatenate((x, [x[0]]))
                y = np.concatenate((y, [y[0]]))
                line.set_data(x, y)

        def set_varlabels(self, labels):
            self.set_thetagrids(np.degrees(theta), labels)

        def _gen_axes_patch(self):
            # The Axes patch must be centered at (0.5, 0.5) and of radius 0.5
            # in axes coordinates.
            if frame == 'circle':
                return Circle((0.5, 0.5), 0.5)
            elif frame == 'polygon':
                return RegularPolygon((0.5, 0.5), num_vars,
                                      radius=.5, edgecolor="k")
            else:
                raise ValueError("unknown value for 'frame': %s" % frame)

        def draw(self, renderer):
            """ Draw. If frame is polygon, make gridlines polygon-shaped """
            if frame == 'polygon':
                gridlines = self.yaxis.get_gridlines()
                for gl in gridlines:
                    gl.get_path()._interpolation_steps = num_vars
            super().draw(renderer)


        def _gen_axes_spines(self):
            if frame == 'circle':
                return super()._gen_axes_spines()
            elif frame == 'polygon':
                # spine_type must be 'left'/'right'/'top'/'bottom'/'circle'.
                spine = Spine(axes=self,
                              spine_type='circle',
                              path=Path.unit_regular_polygon(num_vars))
                # unit_regular_polygon gives a polygon of radius 1 centered at
                # (0, 0) but we want a polygon of radius 0.5 centered at (0.5,
                # 0.5) in axes coordinates.
                spine.set_transform(Affine2D().scale(.5).translate(.5, .5)
                                    + self.transAxes)


                return {'polar': spine}
            else:
                raise ValueError("unknown value for 'frame': %s" % frame)

    register_projection(RadarAxes)
    return theta


def show_radar(title, features):
    
    
    data = [features.keys(),
        (title, [
            features.values(),
        ])]

    N = len(data[0])
    theta = radar_factory(N, frame='polygon')

    spoke_labels = data.pop(0)
    title, case_data = data[0]

    fig = plt.gcf()
    ax = plt.gca()
    fig.subplots_adjust(top=0.85, bottom=0.05)

    ax.set_rgrids([0.2, 0.4, 0.6, 0.8])
    ax.set_title(title,  position=(0.5, 1.1), ha='center')
    ax.set_ylim(0, 1)
    ax.set_yticklabels([])

    for d in case_data:
        line = ax.plot(theta, d)
        ax.fill(theta, d,  alpha=0.25)
    ax.set_varlabels(spoke_labels)

# %%
plt.subplots(2, 3, figsize=(30, 15), subplot_kw={'projection': 'radar'})

plt.subplot(231)
show_radar(title='EEG', features={
    'Portability': 0.9,
    'Time resolution': 0.8,
    'Spatial resolution': 0.2,
    'Non-invasive': 0.9,
    'Low-cost': 0.8,
})

plt.subplot(232)
show_radar(title='MEG', features={
    'Portability': 0.2,
    'Time resolution': 0.3,
    'Spatial resolution': 0.8,
    'Non-invasive': 0.8,
    'Low-cost': 0.1,
})

plt.subplot(233)
show_radar(title='ECoG', features={
    'Portability': 0.5,
    'Time resolution': 0.8,
    'Spatial resolution': 0.7,
    'Non-invasive': 0,
    'Low-cost': 0.1,
})

plt.subplot(234)
show_radar(title='fMRI', features={
    'Portability': 0.1,
    'Time resolution': 0.4,
    'Spatial resolution': 0.5,
    'Non-invasive': 0.9,
    'Low-cost': 0.1,
})

plt.subplot(235)
show_radar(title='NIRS', features={
    'Portability': 0.9,
    'Time resolution': 0.3,
    'Spatial resolution': 0.1,
    'Non-invasive': 0.9,
    'Low-cost': 0.9,
})

plt.subplot(236)
plt.gca().remove()

fig = plt.gcf()
fig.savefig('neuroimaging.svg', bbox_inches='tight')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Development/venv/jupyter/lib/python3.11/site-packages/matplotlib/projections/__init__.py:108, in get_projection_class(projection)
#     107 try:
# --> 108     return projection_registry.get_projection_class(projection)
#     109 except KeyError as err:
#
# File ~/Development/venv/jupyter/lib/python3.11/site-packages/matplotlib/projections/__init__.py:75, in ProjectionRegistry.get_projection_class(self, name)
#      74 """Get a projection class from its *name*."""
# ---> 75 return self._all_projection_types[name]
#
# KeyError: 'radar'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 plt.subplots(2, 3, figsize=(30, 15), subplot_kw=dict(projection='radar'))
#       3 plt.subplot(231)
# ...
